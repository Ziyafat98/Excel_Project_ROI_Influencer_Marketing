# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyafat98/Excel_Project_ROI_Influencer_Marketing/blob/main/4_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Series

# %%
## Əgər Colabdan istifadə etmirsənsə,bu xananı deaktiv et
from google.colab import drive
import os

drive.mount('/content/drive')

possible_dirs = [
    '/content/drive/MyDrive/Python/Introduction2Python/',
    '/content/drive/MyDrive/Introduction2Python/Introduction2Python/',
    '/content/drive/MyDrive/Introduction2Python/',
    '/content/drive/MyDrive/Introduction2Python*/'
]

for dir_path in possible_dirs:
    if os.path.exists(dir_path):
        os.chdir(dir_path)
        break
else:
    print("None of the specified directories exist. Please check the paths.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
###pip install pandas

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread('documents/pandas.jpg')
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.show()

# %% [markdown]
# ##### English
# - "Pandas helps us analyze big data to draw conclusions using statistics. It can tidy up messy data, making it clear and useful."

# %%
import pandas as pd

# %%
pip install pandas

# %%
pd.Series([10, 77, 12, 4, 5])
# Out:
# 0    10
# 1    77
# 2    12
# 3     4
# 4     5
# dtype: int64

# %%
pd.Series([10, 77.5, 12, 4, 5], name= "Mycolumn", index=[1,2,3,4,5])
# Out:
# 1    10.0
# 2    77.5
# 3    12.0
# 4     4.0
# 5     5.0
# Name: Mycolumn, dtype: float64

# %%
number_series = pd.Series([10, 77, 12, 4, 5])
number_series
# Out:
# 0    10
# 1    77
# 2    12
# 3     4
# 4     5
# dtype: int64

# %% [markdown]
# ##### English
# - "To create a pandas Series with a list of numbers, think of it as making a column in a table. It's a straightforward way to organize data."

# %%
# Printing the type of the series

print("Type of 'number_series':", type(number_series))
# Out:
# Type of 'number_series': <class 'pandas.core.series.Series'>

# %%
# Printing the index of the series

print("Index of 'number_series':", number_series.index)
# Out:
# Index of 'number_series': RangeIndex(start=0, stop=5, step=1)

# %%
# Accessing the values in the series

print("Values in 'number_series':", number_series.values)
# Out:
# Values in 'number_series': [10 77 12  4  5]

# %% [markdown]
# ### Creating DataFrame

# %%
info = [
    {'Name': 'Alice', 'Salary': 50000},
    {'Name': 'Bob', 'Salary': 60000},
    {'Name': 'Charlie', 'Salary': 75000},
    {'Name': 'David', 'Salary': 62000},
    {'Name': 'Eve', 'Salary': 55000}
]

# %%
type(info)
# Out:
# list

# %%
#Create a dataframe with columns Name , and Salary and getting data from info list


df = pd.DataFrame(columns=['Name', 'Salary'], data=info)

# %%
#Dataframe is like a table in excel.

df
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   75000
# 3    David   62000
# 4      Eve   55000

# %%
#pd.read_csv()

# %% [markdown]
# ##### English
# - "Press 'Tab' to discover available commands in pandas. It's a quick way to explore options."

# %%
###pip install seaborn
###pip install matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image = mpimg.imread('documents/titanic.jpg')
plt.figure(figsize=(10, 12))
plt.imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4208790288.py in <cell line: 0>()
#       2 import matplotlib.image as mpimg
#       3
# ----> 4 image = mpimg.imread('documents/titanic.jpg')
#       5 plt.figure(figsize=(10, 12))
#       6 plt.imshow(image)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in imread(fname, format)
#    1500             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501             )
# -> 1502     with img_open(fname) as image:
#    1503         return (_pil_png_to_float_array(image)
#    1504                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
# ...

# %% [markdown]
# ##	Reading Data

# %%
import pandas as pd

# %%
#pd.read_csv creates a dataframe from a csv file. Our DataFrame is called titanic_data

titanic_data=pd.read_csv('datasets/TitanicDataset/Titanic_clean.csv')
titanic_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3048586634.py in <cell line: 0>()
#       1 #pd.read_csv creates a dataframe from a csv file. Our DataFrame is called titanic_data
#       2
# ----> 3 titanic_data=pd.read_csv('datasets/TitanicDataset/Titanic_clean.csv')
#       4 titanic_data.head()
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
##help(pd.read_csv)
##?pd.read_csv

# %% [markdown]
# ### Column name descriptions

# %% [markdown]
# | Column Name | English Description                                | Azerbaijani Description                                 |
# |-------------|----------------------------------------------------|--------------------------------------------------------|
# | survived    | Survival status (0 = No, 1 = Yes)                  | Sağ qalma vəziyyəti (0 = Xeyr, 1 = Bəli)                |
# | pclass      | Ticket class (1 = 1st, 2 = 2nd, 3 = 3rd)           | Bilet sinfi (1 = 1-ci sinif, 2 = 2-ci sinif, 3 = 3-cü sinif) |
# | sex         | Gender of the passenger                            | Sərnişinin cinsi                                       |
# | age         | Age of the passenger                               | Sərnişinin yaşı                                        |
# | sibsp       | Number of siblings/spouses aboard                   | Gəmidə olan qardaşlar/ərlərin sayı                     |
# | parch       | Number of parents/children aboard                  | Gəmidə olan valideyn/uşaqların sayı                    |
# | fare        | Passenger fare                                     | Sərnişin haqqı                                         |
# | embarked    | Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton) | Qalxış limanı (C = Şerburq, Q = Kuinstaun, S = Sauthempton) |
# | class       | Ticket class (1st, 2nd, 3rd)                       | Bilet sinfi (1-ci, 2-ci, 3-cü)                         |
# | who         | Person's category (man, woman, child)              | Şəxsin kateqoriyası (kişi, qadın, uşaq)                |
# | adult_male  | Adult male indicator (True/False)                  | Yetkin kişi göstəricisi (Doğru/Yanlış)                 |
# | deck        | Cabin deck                                         | Kabinin palubası                                       |
# | embark_town | Port of Embarkation (Cherbourg, Queenstown, Southampton) | Qalxış limanı (Şerburq, Kuinstaun, Sauthempton)        |
# | alive       | Survival status (yes, no)                          | Sağ qalma vəziyyəti (bəli, xeyr)                       |
# | alone       | Alone indicator (True/False)                       | Təklik göstəricisi (Doğru/Yanlış)                      |

# %% [markdown]
# ##  Data Overview

# %%
# Displaying the fisrt few rows of the dataset
titanic_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2085577083.py in <cell line: 0>()
#       1 # Displaying the fisrt few rows of the dataset
# ----> 2 titanic_data.head()
#
# NameError: name 'titanic_data' is not defined

# %%
# Displaying the last few rows of the dataset

titanic_data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 707         0       3  female  39.0      0      5  29.125        Q   Third
# 708         0       2    male  27.0      0      0  13.000        S  Second
# 709         1       1  female  19.0      0      0  30.000        S   First
# 710         1       1    male  26.0      0      0  30.000        C   First
# 711         0       3    male  32.0      0      0   7.750        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 707  woman       False   Queenstown    no  False
# 708    man        True  Southampton    no   True
# 709  woman       False  Southampton   yes   True
# 710    man        True    Cherbourg   yes   True
# 711    man        True   Queenstown    no   True

# %%
titanic_data.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 654         0       3    male  10.0      3      2   27.9000        S   Third
# 702         1       2  female  25.0      0      1   26.0000        S  Second
# 387         0       1    male  58.0      0      0   29.7000        C   First
# 514         0       3    male  21.0      0      0    8.4333        S   Third
# 240         1       1  female  50.0      0      1  247.5208        C   First
#
#        who  adult_male  embark_town alive  alone
# 654  child       False  Southampton    no  False
# 702  woman       False  Southampton   yes  False
# 387    man        True    Cherbourg    no   True
# 514    man        True  Southampton    no   True
# 240  woman       False    Cherbourg   yes  False

# %%
# Getting the shape of the dataset (number of rows and columns)

titanic_data.shape
# Out:
# (712, 14)

# %% [markdown]
# ### Defining missing values

# %%
  titanic_data.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic_data.isna().mean()*100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %% [markdown]
# ## Checking data type

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
# Displaying a concise summary of the dataset, including the type of each column

titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     712 non-null    int64
#  1   pclass       712 non-null    int64
#  2   sex          712 non-null    object
#  3   age          712 non-null    float64
#  4   sibsp        712 non-null    int64
#  5   parch        712 non-null    int64
#  6   fare         712 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        712 non-null    object
#  9   who          712 non-null    object
#  10  adult_male   712 non-null    bool
#  11  embark_town  712 non-null    object
#  12  alive        712 non-null    object
#  13  alone        712 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(6)
# memory usage: 68.3+ KB

# %%
titanic_data["age"]=titanic_data["age"].astype("int")

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 1         1       1  female   38      1      0  71.2833        C  First
# 2         1       3  female   26      0      0   7.9250        S  Third
# 3         1       1  female   35      1      0  53.1000        S  First
# 4         0       3    male   35      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
# Listing all the column names in the dataset

titanic_data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
titanic_data.columns = [col.lower() for col in titanic_data.columns]

# %%
titanic_data.tail(2)
# Out:
#      survived  pclass   sex  age  sibsp  parch   fare embarked  class  who  \
# 710         1       1  male   26      0      0  30.00        C  First  man
# 711         0       3  male   32      0      0   7.75        Q  Third  man
#
#      adult_male embark_town alive  alone
# 710        True   Cherbourg   yes   True
# 711        True  Queenstown    no   True

# %%
# Accessing the index of the dataframe

titanic_data.index
# Out:
# RangeIndex(start=0, stop=712, step=1)

# %% [markdown]
# # Checking duplicate values

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 1         1       1  female   38      1      0  71.2833        C  First
# 2         1       3  female   26      0      0   7.9250        S  Third
# 3         1       1  female   35      1      0  53.1000        S  First
# 4         0       3    male   35      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
titanic_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 707    False
# 708     True
# 709    False
# 710    False
# 711    False
# Length: 712, dtype: bool

# %%
len(titanic_data[titanic_data.duplicated()])
# Out:
# 41

# %%
titanic_data[titanic_data.duplicated()].shape[0]
# Out:
# 41

# %%
titanic_data.duplicated().sum()
# Out:
# 41

# %%
# titanic_data=titanic_data.drop_duplicates()

# %%
# titanic_data =titanic_data.drop_duplicates()

# %%
titanic_data.drop_duplicates(inplace=True)

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 1         1       1  female   38      1      0  71.2833        C  First
# 2         1       3  female   26      0      0   7.9250        S  Third
# 3         1       1  female   35      1      0  53.1000        S  First
# 4         0       3    male   35      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
titanic_data.shape
# Out:
# (671, 14)

# %% [markdown]
# # Removing index

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 1         1       1  female   38      1      0  71.2833        C  First
# 2         1       3  female   26      0      0   7.9250        S  Third
# 3         1       1  female   35      1      0  53.1000        S  First
# 4         0       3    male   35      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
# List of row indices to be deleted

rows_to_delete = [1, 3, 4]

# %%
# Dropping specified rows from 'data_frame'

titanic_data.drop(index=rows_to_delete).head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 2         1       3  female   26      0      0   7.9250        S  Third
# 5         0       1    male   54      0      0  51.8625        S  First
# 6         0       3    male    2      3      1  21.0750        S  Third
# 7         1       3  female   27      0      2  11.1333        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 2  woman       False  Southampton   yes   True
# 5    man        True  Southampton    no   True
# 6  child       False  Southampton    no  False
# 7  woman       False  Southampton   yes  False

# %%
# Drop  funtion does not delete  values from orginal dataset

titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 1         1       1  female   38      1      0  71.2833        C  First
# 2         1       3  female   26      0      0   7.9250        S  Third
# 3         1       1  female   35      1      0  53.1000        S  First
# 4         0       3    male   35      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
titanic_data.drop(index=rows_to_delete, inplace=True)

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 2         1       3  female   26      0      0   7.9250        S  Third
# 5         0       1    male   54      0      0  51.8625        S  First
# 6         0       3    male    2      3      1  21.0750        S  Third
# 7         1       3  female   27      0      2  11.1333        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 2  woman       False  Southampton   yes   True
# 5    man        True  Southampton    no   True
# 6  child       False  Southampton    no  False
# 7  woman       False  Southampton   yes  False

# %%
# Remove specified rows from 'titanic_data' and assign the result back to 'titanic_data'

###titanic_data = titanic_data.drop(rows_to_delete, axis=0)

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 2         1       3  female   26      0      0   7.9250        S  Third
# 5         0       1    male   54      0      0  51.8625        S  First
# 6         0       3    male    2      3      1  21.0750        S  Third
# 7         1       3  female   27      0      2  11.1333        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 2  woman       False  Southampton   yes   True
# 5    man        True  Southampton    no   True
# 6  child       False  Southampton    no  False
# 7  woman       False  Southampton   yes  False

# %% [markdown]
# # Displaying columns

# %%
titanic_data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
# Displaying the first 5 values from the 'age' column of the DataFrame

titanic_data["age"].head()
#titanic_data.age.head()
# Out:
# 0    22
# 2    26
# 5    54
# 6     2
# 7    27
# Name: age, dtype: int64

# %%
titanic_data.age.head()
# Out:
# 0    22
# 2    26
# 5    54
# 6     2
# 7    27
# Name: age, dtype: int64

# %%
titanic_data[["age", "fare"]].head()
# Out:
#    age     fare
# 0   22   7.2500
# 2   26   7.9250
# 5   54  51.8625
# 6    2  21.0750
# 7   27  11.1333

# %%
# Selecting the 'fare' and 'age' columns

titanic_data[["fare", "age", 'survived']].head()
# Out:
#       fare  age  survived
# 0   7.2500   22         0
# 2   7.9250   26         1
# 5  51.8625   54         0
# 6  21.0750    2         0
# 7  11.1333   27         1

# %%
# List of Titanic dataset column names

titanic_col_names = [ "survived", "pclass", "sex", "age"]

# Selecting the columns
titanic_data[titanic_col_names].head(2)
# Out:
#    survived  pclass     sex  age
# 0         0       3    male   22
# 2         1       3  female   26

# %%
print(titanic_col_names)
# Out:
# ['survived', 'pclass', 'sex', 'age']

# %% [markdown]
# # Dropping  Columns

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 2         1       3  female   26      0      0   7.9250        S  Third
# 5         0       1    male   54      0      0  51.8625        S  First
# 6         0       3    male    2      3      1  21.0750        S  Third
# 7         1       3  female   27      0      2  11.1333        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 2  woman       False  Southampton   yes   True
# 5    man        True  Southampton    no   True
# 6  child       False  Southampton    no  False
# 7  woman       False  Southampton   yes  False

# %%
titanic_data.shape
# Out:
# (668, 14)

# %%
# Permanently dropping the 'name'

titanic_data.drop("embark_town", axis=1, inplace=True)

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 2         1       3  female   26      0      0   7.9250        S  Third
# 5         0       1    male   54      0      0  51.8625        S  First
# 6         0       3    male    2      3      1  21.0750        S  Third
# 7         1       3  female   27      0      2  11.1333        S  Third
#
#      who  adult_male alive  alone
# 0    man        True    no  False
# 2  woman       False   yes   True
# 5    man        True    no   True
# 6  child       False    no  False
# 7  woman       False   yes  False

# %%
titanic_data.drop("who", axis=1, inplace=True)

# %%
titanic_data=titanic_data.drop("class", axis=1)

# %%
titanic_data=titanic_data.drop("alive", axis=1)

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#    alone
# 0  False
# 2   True
# 5   True
# 6  False
# 7  False

# %% [markdown]
# # Add a column

# %%
df=pd.read_csv('datasets/TitanicDataset/Titanic_clean.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
alive_column = df['alive']

# %%
alive_column.head(2)
# Out:
# 0     no
# 1    yes
# Name: alive, dtype: object

# %%
titanic_data['alive'] = df['alive']

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#    alone alive
# 0  False    no
# 2   True   yes
# 5   True    no
# 6  False    no
# 7  False   yes

# %% [markdown]
# # Order Columns

# %%
new_order = ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'adult_male', 'alive', 'alone']

# %%
titanic_data = titanic_data[new_order]

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True
# 5    no   True
# 6    no  False
# 7   yes  False

# %% [markdown]
# ##	Selection in Pandas

# %% [markdown]
# ## Label-based selection

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True
# 5    no   True
# 6    no  False
# 7   yes  False

# %%
titanic_data.loc[5,"age" ]
# Out:
# 54

# %%
titanic_data.loc[6]
# Out:
# survived           0
# pclass             3
# sex             male
# age                2
# sibsp              3
# parch              1
# fare          21.075
# embarked           S
# adult_male     False
# alive             no
# alone          False
# Name: 6, dtype: object

# %%
titanic_data.loc[6, :]
# Out:
# survived           0
# pclass             3
# sex             male
# age                2
# sibsp              3
# parch              1
# fare          21.075
# embarked           S
# adult_male     False
# alive             no
# alone          False
# Name: 6, dtype: object

# %%
titanic_data.loc[:, "age"].head(2)
# Out:
# 0    22
# 2    26
# Name: age, dtype: int64

# %%
titanic_data["age"].head(2)
# Out:
# 0    22
# 2    26
# Name: age, dtype: int64

# %% [markdown]
#  Label-Based:
#  - Accesses data by labels (row and column names or indices)

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True
# 5    no   True
# 6    no  False
# 7   yes  False

# %%
titanic_data.loc[5, "fare"]
# Out:
# 51.8625

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True
# 5    no   True
# 6    no  False
# 7   yes  False

# %%
titanic_data.loc[1:5, ["fare", "age"]]
# Out:
#       fare  age
# 2   7.9250   26
# 5  51.8625   54

# %% [markdown]
# **start and stop are inclusive**

# %%
titanic_data.loc[titanic_data["age"] > 30, ["survived"]].head()
# Out:
#     survived
# 5          0
# 10         1
# 12         0
# 14         1
# 16         0

# %%
titanic_data.head(1)
# Out:
#    survived  pclass   sex  age  sibsp  parch  fare embarked  adult_male alive  \
# 0         0       3  male   22      1      0  7.25        S        True    no
#
#    alone
# 0  False

# %%
titanic_data.columns.str.lower().str.contains("s")
# Out:
# array([ True,  True,  True, False,  True, False, False, False, False,
#        False, False])

# %%
titanic_data.columns.str.lower().str.contains("class")
# Out:
# array([False,  True, False, False, False, False, False, False, False,
#        False, False])

# %%
titanic_data.loc[:]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked  \
# 0           0       3    male   22      1      0   7.2500        S
# 2           1       3  female   26      0      0   7.9250        S
# 5           0       1    male   54      0      0  51.8625        S
# 6           0       3    male    2      3      1  21.0750        S
# 7           1       3  female   27      0      2  11.1333        S
# ..        ...     ...     ...  ...    ...    ...      ...      ...
# 705         0       2    male   28      0      0  10.5000        S
# 707         0       3  female   39      0      5  29.1250        Q
# 709         1       1  female   19      0      0  30.0000        S
# 710         1       1    male   26      0      0  30.0000        C
# 711         0       3    male   32      0      0   7.7500        Q
#
#      adult_male alive  alone
# 0          True    no  False
# 2         False   yes   True
# 5          True    no   True
# 6         False    no  False
# ...

# %%
# Selecting columns in 'titanic_data' whose names contain the string "age"

titanic_data.loc[:, titanic_data.columns.str.lower().str.contains("class")].head()
# Out:
#    pclass
# 0       3
# 2       3
# 5       1
# 6       3
# 7       3

# %%
# Selecting columns in 'titanic_data' whose names do not contain the string "age"

titanic_data.loc[:,~ titanic_data.columns.str.contains("age")].head()
# Out:
#    survived  pclass     sex  sibsp  parch     fare embarked  adult_male alive  \
# 0         0       3    male      1      0   7.2500        S        True    no
# 2         1       3  female      0      0   7.9250        S       False   yes
# 5         0       1    male      0      0  51.8625        S        True    no
# 6         0       3    male      3      1  21.0750        S       False    no
# 7         1       3  female      0      2  11.1333        S       False   yes
#
#    alone
# 0  False
# 2   True
# 5   True
# 6  False
# 7  False

# %%
titanic_data.filter(like="class", axis =1).head()
# Out:
#    pclass
# 0       3
# 2       3
# 5       1
# 6       3
# 7       3

# %% [markdown]
#  ## Position-Based (Index -Based)

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True
# 5    no   True
# 6    no  False
# 7   yes  False

# %%
titanic_data.iloc[1]
# Out:
# survived           1
# pclass             3
# sex           female
# age               26
# sibsp              0
# parch              0
# fare           7.925
# embarked           S
# adult_male     False
# alive            yes
# alone           True
# Name: 2, dtype: object

# %%
# Selecting rows 0 to 2 (exclusive) from the DataFrame

titanic_data.iloc[0:3]
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
#
#   alive  alone
# 0    no  False
# 2   yes   True
# 5    no   True

# %%
len(titanic_data.columns)
# Out:
# 11

# %%
# Selecting the value at row 0 and column 2

titanic_data.iloc[0, 3]
# Out:
# 22

# %%
titanic_data.iloc[1, 6]
# Out:
# 7.925

# %%
# Rows: 0 to 2 (inclusive), Columns: 0 to 2 (inclusive)

titanic_data.iloc[0:3, 0:3]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 2         1       3  female
# 5         0       1    male

# %%
# Selecting the 'age' column for rows labeled 0 to 3 (inclusive)

titanic_data.loc[0:3, "age"]
# Out:
# 0    22
# 2    26
# Name: age, dtype: int64

# %% [markdown]
#  ## Conditional Selection

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True
# 5    no   True
# 6    no  False
# 7   yes  False

# %%
titanic_data[titanic_data['age'] > 20].head(2)
# Out:
#    survived  pclass     sex  age  sibsp  parch   fare embarked  adult_male  \
# 0         0       3    male   22      1      0  7.250        S        True
# 2         1       3  female   26      0      0  7.925        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True

# %%
# Selecting rows  where 'age' is greater than 50

titanic_data[titanic_data["age"] > 50].head()
# Out:
#     survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 5          0       1    male   54      0      0  51.8625        S        True
# 10         1       1  female   58      0      0  26.5500        S       False
# 14         1       2  female   55      0      0  16.0000        S       False
# 25         0       2    male   66      0      0  10.5000        S        True
# 40         0       1    male   65      0      1  61.9792        C        True
#
#    alive  alone
# 5     no   True
# 10   yes   True
# 14   yes   True
# 25    no   True
# 40    no  False

# %%
# Selecting where the gender is 'male'

titanic_data[titanic_data["sex"] == 'male'].head()
# Out:
#     survived  pclass   sex  age  sibsp  parch     fare embarked  adult_male  \
# 0          0       3  male   22      1      0   7.2500        S        True
# 5          0       1  male   54      0      0  51.8625        S        True
# 6          0       3  male    2      3      1  21.0750        S       False
# 11         0       3  male   20      0      0   8.0500        S        True
# 12         0       3  male   39      1      5  31.2750        S        True
#
#    alive  alone
# 0     no  False
# 5     no   True
# 6     no  False
# 11    no   True
# 12    no  False

# %%
titanic_data.loc[(titanic_data["age"] > 20) &  (titanic_data["sex"] == "male") & titanic_data["survived"] == 0 ].head(2)
# Out:
#    survived  pclass     sex  age  sibsp  parch   fare embarked  adult_male  \
# 0         0       3    male   22      1      0  7.250        S        True
# 2         1       3  female   26      0      0  7.925        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True

# %%
# Selecting  where 'age' is greater than 20 and 'sex' is 'male',

titanic_data.loc[(titanic_data["age"] > 20) & (titanic_data["sex"] == "male"), ["age", "sex"]].head()
# Out:
#     age   sex
# 0    22  male
# 5    54  male
# 12   39  male
# 17   35  male
# 18   34  male

# %% [markdown]
# *   **& - and**
# *   **| - or**

# %%
titanic_data.query("(age >20 and sex == 'male')").head()
# Out:
#     survived  pclass   sex  age  sibsp  parch     fare embarked  adult_male  \
# 0          0       3  male   22      1      0   7.2500        S        True
# 5          0       1  male   54      0      0  51.8625        S        True
# 12         0       3  male   39      1      5  31.2750        S        True
# 17         0       2  male   35      0      0  26.0000        S        True
# 18         1       2  male   34      0      0  13.0000        S        True
#
#    alive  alone
# 0     no  False
# 5     no   True
# 12    no  False
# 17    no   True
# 18   yes   True

# %%
titanic_data.query("(age >20 and sex == 'male') or (fare< 50)")[["age", "fare"]] .head()
# Out:
#    age     fare
# 0   22   7.2500
# 2   26   7.9250
# 5   54  51.8625
# 6    2  21.0750
# 7   27  11.1333

# %%
# 'embark' is either 'Southampton' or 'Cherbourg'

titanic_data.loc[(titanic_data["embarked"] == "S") | (titanic_data["embarked"] == "Q")].head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male   22      1      0   7.2500        S        True
# 2         1       3  female   26      0      0   7.9250        S       False
# 5         0       1    male   54      0      0  51.8625        S        True
# 6         0       3    male    2      3      1  21.0750        S       False
# 7         1       3  female   27      0      2  11.1333        S       False
#
#   alive  alone
# 0    no  False
# 2   yes   True
# 5    no   True
# 6    no  False
# 7   yes  False

# %%
titanic_data.loc[titanic_data["sex"].isin(["male"])].head()
# Out:
#     survived  pclass   sex  age  sibsp  parch     fare embarked  adult_male  \
# 0          0       3  male   22      1      0   7.2500        S        True
# 5          0       1  male   54      0      0  51.8625        S        True
# 6          0       3  male    2      3      1  21.0750        S       False
# 11         0       3  male   20      0      0   8.0500        S        True
# 12         0       3  male   39      1      5  31.2750        S        True
#
#    alive  alone
# 0     no  False
# 5     no   True
# 6     no  False
# 11    no   True
# 12    no  False

# %% [markdown]
# *   | Logical OR
# *   & Logical AND
# *   ~ Logical NOT

# %% [markdown]
# # Rename the column

# %%
titanic_data.rename(columns={'sex': 'gender'}, inplace=True)

# %%
titanic_data.rename(columns={'sex': 'gender', 'age': 'person_age', 'fare': 'ticket_price'}, inplace=True)
titanic_data.head()
# Out:
#    survived  pclass  gender  person_age  sibsp  parch  ticket_price embarked  \
# 0         0       3    male          22      1      0        7.2500        S
# 2         1       3  female          26      0      0        7.9250        S
# 5         0       1    male          54      0      0       51.8625        S
# 6         0       3    male           2      3      1       21.0750        S
# 7         1       3  female          27      0      2       11.1333        S
#
#    adult_male alive  alone
# 0        True    no  False
# 2       False   yes   True
# 5        True    no   True
# 6       False    no  False
# 7       False   yes  False

# %% [markdown]
#  ## Aggregation with Grouping

# %% [markdown]
# | Aggregation | English Description                                   |
# |-------------|-------------------------------------------------------|
# | count()     | Count the number of non-NA/null entries in each column. |
# | sum()       | Calculate the sum of each numeric column.            |
# | max()       | Find the maximum value in each column.               |
# | min()       | Find the minimum value in each column.               |
# | first()     | Get the first non-NA value in each column.            |
# | last()      | Get the last non-NA value in each column.             |
# | mean()      | Calculate the mean (average) of each numeric column. |

# %%
titanic_data.head()
# Out:
#    survived  pclass  gender  person_age  sibsp  parch  ticket_price embarked  \
# 0         0       3    male          22      1      0        7.2500        S
# 2         1       3  female          26      0      0        7.9250        S
# 5         0       1    male          54      0      0       51.8625        S
# 6         0       3    male           2      3      1       21.0750        S
# 7         1       3  female          27      0      2       11.1333        S
#
#    adult_male alive  alone
# 0        True    no  False
# 2       False   yes   True
# 5        True    no   True
# 6       False    no  False
# 7       False   yes  False

# %%
# Calculate the average age of all passengers

average_age = titanic_data["person_age"].mean()
average_age
# Out:
# 29.709580838323355

# %%
# Calculate the average age by gender

average_age_by_gender = titanic_data.groupby("gender")["person_age"].mean()
average_age_by_gender
# Out:
# gender
# female    27.644000
# male      30.944976
# Name: person_age, dtype: float64

# %%
titanic_data.groupby("gender").agg({"person_age" : ["mean", "min", 'max']} )
# Out:
#        person_age
#              mean min max
# gender
# female  27.644000   0  63
# male    30.944976   0  80

# %%
# Using a dictionary to specify aggregation methods for different columns

age_stats_by_gender = titanic_data.groupby("gender").agg({"person_age": ["mean", "min", 'max']})
age_stats_by_gender
# Out:
#        person_age
#              mean min max
# gender
# female  27.644000   0  63
# male    30.944976   0  80

# %%
# Combining multiple aggregations for different columns

combined_stats = titanic_data.groupby("gender").agg({
    "person_age": "max",
    "survived": "mean"
})
combined_stats
# Out:
#         person_age  survived
# gender
# female          63  0.744000
# male            80  0.220096

# %%
titanic_data.groupby(["gender", "pclass"]).agg({
    "person_age": "mean",
    "survived": "mean" ,
    'gender': 'count'
}).rename(columns={"gender":"count"})
# Out:
#                person_age  survived  count
# gender pclass
# female 1        34.312500  0.962500     80
#        2        28.260870  0.913043     69
#        3        21.940594  0.455446    101
# male   1        41.060000  0.400000    100
#        2        31.045455  0.170455     88
#        3        26.508696  0.160870    230

# %%
titanic_data.head()
# Out:
#    survived  pclass  gender  person_age  sibsp  parch  ticket_price embarked  \
# 0         0       3    male          22      1      0        7.2500        S
# 2         1       3  female          26      0      0        7.9250        S
# 5         0       1    male          54      0      0       51.8625        S
# 6         0       3    male           2      3      1       21.0750        S
# 7         1       3  female          27      0      2       11.1333        S
#
#    adult_male alive  alone
# 0        True    no  False
# 2       False   yes   True
# 5        True    no   True
# 6       False    no  False
# 7       False   yes  False

# %%
# Grouping by multiple columns and calculating different statistics

titanic_data.groupby(["gender", "embarked", "pclass"]).agg({
    "person_age": "mean",
    "survived": "mean" ,
    'gender': 'count'
}).rename(columns={"gender": "count"})

#Port of Embarkation (Cherbourg, Queenstown, Southampton)
# Out:
#                         person_age  survived  count
# gender embarked pclass
# female C        1        36.333333  0.972222     36
#                 2        19.142857  1.000000      7
#                 3        14.866667  0.666667     15
#        Q        1        33.000000  1.000000      1
#                 2        30.000000  1.000000      1
#                 3        22.800000  0.500000     10
#        S        1        32.651163  0.953488     43
#                 2        29.278689  0.901639     61
#                 3        23.223684  0.407895     76
# male   C        1        40.111111  0.444444     36
#                 2        25.875000  0.125000      8
#                 3        24.920000  0.280000     25
#        Q        1        44.000000  0.000000      1
#                 2        57.000000  0.000000      1
#                 3        28.071429  0.071429     14
#        S        1        41.555556  0.380952     63
#                 2        31.240506  0.177215     79
# ...

# %%
titanic_data.groupby(["embarked"]).agg({
    "person_age": "mean",
    "survived": "mean" ,
    'gender': 'count'
}).rename(columns={"gender": "count"})
#Port of Embarkation (Cherbourg, Queenstown, Southampton)
# Out:
#           person_age  survived  count
# embarked
# C          31.015748  0.598425    127
# Q          28.035714  0.285714     28
# S          29.477583  0.378168    513

# %%
# Grouping by multiple columns and calculating different statistics

titanic_data.groupby(["gender", "pclass"]).agg({
    "person_age": "mean",
    "survived": "mean",
    'gender' : 'count'
})
# Out:
#                person_age  survived  gender
# gender pclass
# female 1        34.312500  0.962500      80
#        2        28.260870  0.913043      69
#        3        21.940594  0.455446     101
# male   1        41.060000  0.400000     100
#        2        31.045455  0.170455      88
#        3        26.508696  0.160870     230

# %%
# We also need the number of person in each group to make a righ analyse

titanic_data.groupby(["gender", "embarked", "pclass"]).agg({
    "person_age": "mean",
    "survived": "mean",
    "gender": "count"}).rename(columns={"gender": "count"})
# Out:
#                         person_age  survived  count
# gender embarked pclass
# female C        1        36.333333  0.972222     36
#                 2        19.142857  1.000000      7
#                 3        14.866667  0.666667     15
#        Q        1        33.000000  1.000000      1
#                 2        30.000000  1.000000      1
#                 3        22.800000  0.500000     10
#        S        1        32.651163  0.953488     43
#                 2        29.278689  0.901639     61
#                 3        23.223684  0.407895     76
# male   C        1        40.111111  0.444444     36
#                 2        25.875000  0.125000      8
#                 3        24.920000  0.280000     25
#        Q        1        44.000000  0.000000      1
#                 2        57.000000  0.000000      1
#                 3        28.071429  0.071429     14
#        S        1        41.555556  0.380952     63
#                 2        31.240506  0.177215     79
# ...

# %%
titanic_data.head(3)
# Out:
#    survived  pclass  gender  person_age  sibsp  parch  ticket_price embarked  \
# 0         0       3    male          22      1      0        7.2500        S
# 2         1       3  female          26      0      0        7.9250        S
# 5         0       1    male          54      0      0       51.8625        S
#
#    adult_male alive  alone
# 0        True    no  False
# 2       False   yes   True
# 5        True    no   True

# %%
# Family size analysis

titanic_data["family_size"] = titanic_data["sibsp"] + titanic_data["parch"]
family_size_survival = titanic_data.groupby(["family_size"]).agg({
    "survived":["mean" , 'count']
}).reset_index()
family_size_survival
# Out:
#   family_size  survived
#                    mean count
# 0           0  0.336088   363
# 1           1  0.540741   135
# 2           2  0.569892    93
# 3           3  0.769231    26
# 4           4  0.272727    11
# 5           5  0.136364    22
# 6           6  0.333333    12
# 7           7  0.000000     6

# %% [markdown]
# # Embarkation port analysis

# %% [markdown]
# - Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)
# -  Qalxış limanı (C = Şerburq, Q = Kuinstaun, S = Sauthempton) |

# %%
titanic_data.head()
# Out:
#    survived  pclass  gender  person_age  sibsp  parch  ticket_price embarked  \
# 0         0       3    male          22      1      0        7.2500        S
# 2         1       3  female          26      0      0        7.9250        S
# 5         0       1    male          54      0      0       51.8625        S
# 6         0       3    male           2      3      1       21.0750        S
# 7         1       3  female          27      0      2       11.1333        S
#
#    adult_male alive  alone  family_size
# 0        True    no  False            1
# 2       False   yes   True            0
# 5        True    no   True            0
# 6       False    no  False            4
# 7       False   yes  False            2

# %%
titanic_data.groupby(["embarked"]).agg({"survived":["mean" , 'count']}).reset_index()
# Out:
#   embarked  survived
#                 mean count
# 0        C  0.598425   127
# 1        Q  0.285714    28
# 2        S  0.378168   513

# %%
embarkation_survival = titanic_data.groupby(["embarked"]).agg({
    "survived": ["mean" , 'count']
}).reset_index()
embarkation_survival
# Out:
#   embarked  survived
#                 mean count
# 0        C  0.598425   127
# 1        Q  0.285714    28
# 2        S  0.378168   513

# %% [markdown]
# ##  Pivot table

# %% [markdown]
# - Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)
# -  Qalxış limanı (C = Şerburq, Q = Kuinstaun, S = Sauthempton) |

# %%
titanic_data.pivot_table(values='survived', index="gender", columns="embarked", aggfunc=["mean", "count"])
# Out:
#               mean                     count
# embarked         C         Q         S     C   Q    S
# gender
# female    0.896552  0.583333  0.705556    58  12  180
# male      0.347826  0.062500  0.201201    69  16  333

# %%
survival_rates = titanic_data.pivot_table(values='survived', index='gender', columns='embarked', aggfunc='mean')
survival_rates
# Out:
# embarked         C         Q         S
# gender
# female    0.896552  0.583333  0.705556
# male      0.347826  0.062500  0.201201

# %% [markdown]
# ##### English
# - "To analyze survival rates by gender and embarked point, create a pivot table. Use 'survived' as the value, 'sex' as rows, and 'embarked' as columns. Use the 'mean' function to find the average survival rate for each group."

# %% [markdown]
# - Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)
# -  Qalxış limanı (C = Şerburq, Q = Kuinstaun, S = Sauthempton) |

# %%
titanic_data.pivot_table(values='survived', index='gender', columns='embarked', aggfunc=['sum', "count"])
# Out:
#          sum         count
# embarked   C  Q    S     C   Q    S
# gender
# female    52  7  127    58  12  180
# male      24  1   67    69  16  333

# %%
titanic_data["age_group"] = pd.cut(titanic_data["person_age"], bins=[0, 18, 30, 50, 100], labels=["0-18", "19-30", "31-50", "50+"])

# %%
titanic_data[["age_group", 'person_age']].head()
# Out:
#   age_group  person_age
# 0     19-30          22
# 2     19-30          26
# 5       50+          54
# 6      0-18           2
# 7     19-30          27

# %%
age_fare_survival = titanic_data.pivot_table(index=["age_group", "pclass"],
                                             values=["person_age", "ticket_price", "survived"],
                                             aggfunc={"ticket_price": "mean", "survived": ["mean", 'count']}).reset_index()


age_fare_survival
# Out:
# <ipython-input-669-828905af09d3>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   age_fare_survival = titanic_data.pivot_table(index=["age_group", "pclass"],
#    age_group pclass survived           ticket_price
#                        count      mean         mean
# 0       0-18      1       15  0.866667   121.590553
# 1       0-18      2       25  0.800000    26.756168
# 2       0-18      3       89  0.337079    19.496398
# 3      19-30      1       44  0.704545    96.608995
# 4      19-30      2       58  0.448276    22.294397
# 5      19-30      3      145  0.248276    10.275630
# 6      31-50      1       83  0.662651    89.137201
# 7      31-50      2       56  0.464286    21.687054
# 8      31-50      3       85  0.164706    13.103086
# 9        50+      1       37  0.459459    63.676465
# ...

# %%
titanic_data.drop('age_group', axis=1, inplace=True)

# %%
titanic_data.head()
# Out:
#    survived  pclass  gender  person_age  sibsp  parch  ticket_price embarked  \
# 0         0       3    male          22      1      0        7.2500        S
# 2         1       3  female          26      0      0        7.9250        S
# 5         0       1    male          54      0      0       51.8625        S
# 6         0       3    male           2      3      1       21.0750        S
# 7         1       3  female          27      0      2       11.1333        S
#
#    adult_male alive  alone  family_size
# 0        True    no  False            1
# 2       False   yes   True            0
# 5        True    no   True            0
# 6       False    no  False            4
# 7       False   yes  False            2

# %% [markdown]
# ## Missing values

# %%
import seaborn as sns
titanic_data = sns.load_dataset('titanic')

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
 titanic_data[titanic_data.isnull().any(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ##### English
# - "There are missing values in the 'cabin' and 'age' columns."

# %%
# Checking if there are any missing values in the dataset

titanic_data.isnull().values.any()
# Out:
# True

# %%
# Checking the count of missing values in each column of the DataFrame

titanic_data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#The percentages of missing value

titanic_data.isna().mean().round(4) * 100
# Out:
# survived        0.00
# pclass          0.00
# sex             0.00
# age            19.87
# sibsp           0.00
# parch           0.00
# fare            0.00
# embarked        0.22
# class           0.00
# who             0.00
# adult_male      0.00
# deck           77.22
# embark_town     0.22
# alive           0.00
# alone           0.00
# dtype: float64

# %% [markdown]
# ### Filling missing values in  Age columns

# %%
plt.figure(figsize=(8, 6))
titanic_data['age'].hist(density =True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
### Fill missing age values with the median age using lambda function

median_age = titanic_data['age'].median()
median_age
# Out:
# 28.0

# %%
titanic_data['age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_data[titanic_data['age'].isnull()].sample(10)
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 524         0       3    male  NaN      0      0   7.2292        C  Third
# 773         0       3    male  NaN      0      0   7.2250        C  Third
# 301         1       3    male  NaN      2      0  23.2500        Q  Third
# 598         0       3    male  NaN      0      0   7.2250        C  Third
# 425         0       3    male  NaN      0      0   7.2500        S  Third
# 364         0       3    male  NaN      1      0  15.5000        Q  Third
# 768         0       3    male  NaN      1      0  24.1500        Q  Third
# 611         0       3    male  NaN      0      0   7.0500        S  Third
# 55          1       1    male  NaN      0      0  35.5000        S  First
# 180         0       3  female  NaN      8      2  69.5500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 524    man        True  NaN    Cherbourg    no   True
# ...

# %%
median_age
# Out:
# 28.0

# %%
titanic_data['age'].fillna(median_age, inplace=True)
# Out:
# <ipython-input-683-5d8d392a4070>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_data['age'].fillna(median_age, inplace=True)

# %%
titanic_data['age_filled'] = titanic_data['age'].apply(lambda x: titanic_data['age'].median() if pd.isnull(x) else x)

# %%
titanic_data['age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
titanic_data.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_filled
# 0    man        True  NaN  Southampton    no  False        22.0
# 1  woman       False    C    Cherbourg   yes  False        38.0
# 2  woman       False  NaN  Southampton   yes   True        26.0

# %%
titanic_data.isna().mean()*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age             0.000000
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# age_filled      0.000000
# dtype: float64

# %% [markdown]
# ### Filling missing values in  Deck columns

# %%
titanic_data.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 497         0       3    male  28.0      0      0  15.1000        S   Third
# 750         1       2  female   4.0      1      1  23.0000        S  Second
# 774         1       2  female  54.0      1      3  23.0000        S  Second
# 473         1       2  female  23.0      0      0  13.7917        C  Second
# 35          0       1    male  42.0      1      0  52.0000        S   First
# 231         0       3    male  29.0      0      0   7.7750        S   Third
# 602         0       1    male  28.0      0      0  42.4000        S   First
# 863         0       3  female  28.0      8      2  69.5500        S   Third
# 106         1       3  female  21.0      0      0   7.6500        S   Third
# 117         0       2    male  29.0      1      0  21.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone  age_filled
# 497    man        True  NaN  Southampton    no   True        28.0
# ...

# %% [markdown]
# | Column Name | English Description                                | Azerbaijani Description                                 |
# |-------------|----------------------------------------------------|--------------------------------------------------------|
# | survived    | Survival status (0 = No, 1 = Yes)                  | Sağ qalma vəziyyəti (0 = Xeyr, 1 = Bəli)                |
# | pclass      | Ticket class (1 = 1st, 2 = 2nd, 3 = 3rd)           | Bilet sinfi (1 = 1-ci sinif, 2 = 2-ci sinif, 3 = 3-cü sinif) |
# | sex         | Gender of the passenger                            | Sərnişinin cinsi                                       |
# | age         | Age of the passenger                               | Sərnişinin yaşı                                        |
# | sibsp       | Number of siblings/spouses aboard                   | Gəmidə olan qardaşlar/ərlərin sayı                     |
# | parch       | Number of parents/children aboard                  | Gəmidə olan valideyn/uşaqların sayı                    |
# | fare        | Passenger fare                                     | Sərnişin haqqı                                         |
# | embarked    | Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton) | Qalxış limanı (C = Şerburq, Q = Kuinstaun, S = Sauthempton) |
# | class       | Ticket class (1st, 2nd, 3rd)                       | Bilet sinfi (1-ci, 2-ci, 3-cü)                         |
# | who         | Person's category (man, woman, child)              | Şəxsin kateqoriyası (kişi, qadın, uşaq)                |
# | adult_male  | Adult male indicator (True/False)                  | Yetkin kişi göstəricisi (Doğru/Yanlış)                 |
# | deck        | Cabin deck                                         | Kabinin palubası                                       |
# | embark_town | Port of Embarkation (Cherbourg, Queenstown, Southampton) | Qalxış limanı (Şerburq, Kuinstaun, Sauthempton)        |
# | alive       | Survival status (yes, no)                          | Sağ qalma vəziyyəti (bəli, xeyr)                       |
# | alone       | Alone indicator (True/False)                       | Təklik göstəricisi (Doğru/Yanlış)                      |

# %%
titanic_data[['deck']].value_counts().reset_index().sort_values('count' , ascending=False)
# Out:
#   deck  count
# 0    C     59
# 1    B     47
# 2    D     33
# 3    E     32
# 4    A     15
# 5    F     13
# 6    G      4

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the image using PIL
image = Image.open('documents/Olympic_&_Titanic_cutaway_diagram.png')

# Display the image
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ##### English
# - "The deck letters (e.g., A, B, C, D, E, F, G) on the Titanic represent different levels, with A being the highest and G the lowest. First-Class passengers typically had cabins on higher decks, like B and C, while Second-Class and Third-Class cabins were on lower decks."

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
deck_order = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
sns.set(style="whitegrid")
plt.figure(figsize=(15, 20))
sns.catplot(
    data=titanic_data,
    x="deck",
    hue="class",
    kind="count",
    order=deck_order,
)
plt.xlabel("Deck")
plt.ylabel("Count")
plt.title("Passenger Count by Deck and Class")
plt.xticks(rotation=45)
plt.show()

# %%
mean_fare_by_deck = titanic_data.groupby('class')['deck'].agg(lambda x: x.mode().iloc[0])
s = mean_fare_by_deck.reset_index()
s
# Out:
# <ipython-input-693-d59146ad5e51>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_fare_by_deck = titanic_data.groupby('class')['deck'].agg(lambda x: x.mode().iloc[0])
#     class deck
# 0   First    C
# 1  Second    F
# 2   Third    F

# %%
titanic_data['deck'] = titanic_data.groupby('class')['deck'].transform(lambda x: x.fillna(x.mode().iloc[0]))
# Out:
# <ipython-input-694-7f7261787691>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic_data['deck'] = titanic_data.groupby('class')['deck'].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_filled
# 0    man        True    F  Southampton    no  False        22.0
# 1  woman       False    C    Cherbourg   yes  False        38.0
# 2  woman       False    F  Southampton   yes   True        26.0
# 3  woman       False    C  Southampton   yes  False        35.0
# 4    man        True    F  Southampton    no   True        35.0

# %% [markdown]
# # compare the values after filling

# %%
titanic_data.isna().mean().round(4) * 100
# Out:
# survived       0.00
# pclass         0.00
# sex            0.00
# age            0.00
# sibsp          0.00
# parch          0.00
# fare           0.00
# embarked       0.22
# class          0.00
# who            0.00
# adult_male     0.00
# deck           0.00
# embark_town    0.22
# alive          0.00
# alone          0.00
# age_filled     0.00
# dtype: float64

# %%
titanic_data.shape
# Out:
# (891, 16)

# %%
#We can drop the other row which has missing value

titanic_data.dropna(inplace=True)

# %%
titanic_data.shape
# Out:
# (889, 16)

# %%
#Or we can filling the rest  missing value with 'unknow'
titanic_data['embarked'].fillna('unknown')
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 889, dtype: object

# %% [markdown]
# ## Join Operations

# %%
# Sample data for employees

data_employees = {
    'EmpID': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'DeptID': [101, 102, 101, 103]
}

# %%
# Sample data for departments

data_departments = {
    'DeptID': [101, 102, 103, 104],
    'DeptName': ['HR', 'Finance', 'IT', 'Marketing']
}

# %%
# Creating DataFrames

df_employees = pd.DataFrame(data_employees)
df_departments = pd.DataFrame(data_departments)

# %%
df_employees
# Out:
#    EmpID     Name  DeptID
# 0      1    Alice     101
# 1      2      Bob     102
# 2      3  Charlie     101
# 3      4    David     103

# %%
df_departments
# Out:
#    DeptID   DeptName
# 0     101         HR
# 1     102    Finance
# 2     103         IT
# 3     104  Marketing

# %%
# Joining the datasets on DeptID

merged_df = pd.merge(df_employees, df_departments, on='DeptID')
merged_df
# Out:
#    EmpID     Name  DeptID DeptName
# 0      1    Alice     101       HR
# 1      2      Bob     102  Finance
# 2      3  Charlie     101       HR
# 3      4    David     103       IT

# %% [markdown]
# ### For more information about join and merge
# https://pandas.pydata.org/docs/user_guide/merging.html
